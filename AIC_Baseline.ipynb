# %% [markdown]
# # **1. Install Packages and Data Loader/Downloader**
# In this section, we have to install some essential packages for pipeline and set up a `Data Loader` and `Data Downloader` from Kaggle/Google Drive.
#
# The dataset includes:
# - Keyframes of each video
# - Videos
# - Metadata
# - Objects Json

# %%
# !rm -rf /content/drive/MyDrive/datasets/ai-challenge-2025
# !rm -rf /content/drive/MyDrive/.cache/kagglehub
# !mkdir -p /content/drive/MyDrive/datasets
# !mkdir -p /content/drive/MyDrive/.cache/kagglehub
# !mkdir -p /content/drive/MyDrive/tmp

# %%
# !pip install -q transformers gdown torch torchaudio torchvision
# !pip install -q numpy matplotlib pandas
# !pip install -q kagglehub

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, tempfile

os.environ["KAGGLEHUB_CACHE"] = "/content/drive/MyDrive/.cache/kagglehub"
os.environ["TMPDIR"] = "/content/drive/MyDrive/tmp"
tempfile.tempdir = "/content/drive/MyDrive/tmp"

# %%
import kagglehub

DATASET_DIR = "/content/drive/MyDrive/datasets/ai-challenge-2025"

path = kagglehub.dataset_download(
        "aresusayhi/ai-challenge-2025",
        output_dir=DATASET_DIR,
        force_download=True,
    )

print(path)
# Out:
# ...
#  74%|███████▎  | 86.8G/118G [18:02<06:29, 86.1MB/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /content/drive/MyDrive/tmp/ipykernel_11336/2031785862.py in <cell line: 0>()
#       3 DATASET_DIR = "/content/drive/MyDrive/datasets/ai-challenge-2025"
#       4
# ----> 5 path = kagglehub.dataset_download(
#       6         "aresusayhi/ai-challenge-2025",
#       7         output_dir=DATASET_DIR,
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/datasets.py in dataset_download(handle, path, force_download, output_dir)
#      50     h = parse_dataset_handle(handle)
#      51     logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52     resolved_path, _ = registry.dataset_resolver(
#      53         h,
#      54         path,
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/registry.py in __call__(self, *args, **kwargs)
# ...

# %%
# !du -sh /content/drive/MyDrive/datasets/ai-challenge-2025
# !du -sh /content/drive/MyDrive/.cache/kagglehub
# Out:
# 4.0K	/content/drive/MyDrive/datasets/ai-challenge-2025
# 4.0K	/content/drive/MyDrive/.cache/kagglehub
