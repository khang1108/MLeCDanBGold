# %%
import pandas as pd

df = pd.read_parquet("artifacts/enrichment/context/frame_context_v1.parquet")

# %%
df.columns
# Out:
# Index(['frame_id', 'video_id', 'frame_idx', 'timestamp_ms', 'caption_text',
#        'ocr_text', 'object_summary', 'context_text', 'caption_available',
#        'ocr_quality', 'object_count', 'context_version', 'caption_version',
#        'ocr_version', 'object_version', 'frame_store_id'],
#       dtype='str')

# %%
print(df['context_text'][0])
# Out:
# [CAPTION]
# An advertisement for a tv show with a city in the background.<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# [VISIBLE_TEXT]
# HTVO 06:30:11 giay
#
# [OBJECTS]
# skyscraper x7; tower x3; lantern x2; poster x1
